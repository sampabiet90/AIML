# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/MyDrive/"
# Out:
# 'Colab Notebooks'  'Copy of BikeIndia.csv'  'NEW DOCS.zip'

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Copy of BikeIndia.csv')
df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  01-01-2018       1   0     1        0        6           0
# 1        2  02-01-2018       1   0     1        0        0           0
# 2        3  03-01-2018       1   0     1        0        1           1
# 3        4  04-01-2018       1   0     1        0        2           1
# 4        5  05-01-2018       1   0     1        0        3           1
#
#    weathersit       temp     atemp      hum  windspeed  casual  registered  \
# 0           2  14.110847  18.18125  80.5833  10.749882     331         654
# 1           2  14.902598  17.68695  69.6087  16.652113     131         670
# 2           1   8.050924   9.47025  43.7273  16.636703     120        1229
# 3           1   8.200000  10.60610  59.0435  10.739832     108        1454
# 4           1   9.305237  11.46350  43.6957  12.522300      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
df.head(20)
# Out:
#     instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0         1  01-01-2018       1   0     1        0        6           0
# 1         2  02-01-2018       1   0     1        0        0           0
# 2         3  03-01-2018       1   0     1        0        1           1
# 3         4  04-01-2018       1   0     1        0        2           1
# 4         5  05-01-2018       1   0     1        0        3           1
# 5         6  06-01-2018       1   0     1        0        4           1
# 6         7  07-01-2018       1   0     1        0        5           1
# 7         8  08-01-2018       1   0     1        0        6           0
# 8         9  09-01-2018       1   0     1        0        0           0
# 9        10  10-01-2018       1   0     1        0        1           1
# 10       11  11-01-2018       1   0     1        0        2           1
# 11       12  12-01-2018       1   0     1        0        3           1
# 12       13  13-01-2018       1   0     1        0        4           1
# 13       14  14-01-2018       1   0     1        0        5           1
# 14       15  15-01-2018       1   0     1        0        6           0
# 15       16  16-01-2018       1   0     1        0        0           0
# 16       17  17-01-2018       1   0     1        1        1           0
# 17       18  18-01-2018       1   0     1        0        2           1
# 18       19  19-01-2018       1   0     1        0        3           1
# 19       20  20-01-2018       1   0     1        0        4           1
#
#     weathersit       temp     atemp      hum  windspeed  casual  registered  \
# 0            2  14.110847  18.18125  80.5833  10.749882     331         654
# 1            2  14.902598  17.68695  69.6087  16.652113     131         670
# 2            1   8.050924   9.47025  43.7273  16.636703     120        1229
# 3            1   8.200000  10.60610  59.0435  10.739832     108        1454
# 4            1   9.305237  11.46350  43.6957  12.522300      82        1518
# 5            1   8.378268  11.66045  51.8261   6.000868      88        1518
# 6            2   8.057402  10.44195  49.8696  11.304642     148        1362
# 7            2   6.765000   8.11270  53.5833  17.875868      68         891
# 8            1   5.671653   5.80875  43.4167  24.250650      54         768
# 9            1   6.184153   7.54440  48.2917  14.958889      41        1280
# 10           2   6.932731   9.57320  68.6364   8.182844      43        1220
# 11           1   7.081807   8.02365  59.9545  20.410009      25        1137
# 12           1   6.765000   7.54415  47.0417  20.167000      38        1368
# 13           1   6.595670   9.42065  53.7826   8.478716      54        1367
# 14           2   9.566653  12.40560  49.8750  10.583521     222        1026
# 15           1   9.498347  11.71085  48.3750  12.625011     251         953
# 16           2   7.209153   8.83855  53.7500  12.999139     117         883
# 17           2   8.883347  11.61665  86.1667   9.833925       9         674
# 18           2  11.979134  14.92110  74.1739  13.957239      78        1572
# 19           2  10.728347  12.75250  53.8333  13.125568      83        1844
#
#      cnt
# 0    985
# 1    801
# 2   1349
# 3   1562
# 4   1600
# 5   1606
# 6   1510
# 7    959
# 8    822
# 9   1321
# 10  1263
# 11  1162
# 12  1406
# 13  1421
# 14  1248
# 15  1204
# 16  1000
# 17   683
# 18  1650
# 19  1927

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     730 non-null    int64
#  1   dteday      730 non-null    object
#  2   season      730 non-null    int64
#  3   yr          730 non-null    int64
#  4   mnth        730 non-null    int64
#  5   holiday     730 non-null    int64
#  6   weekday     730 non-null    int64
#  7   workingday  730 non-null    int64
#  8   weathersit  730 non-null    int64
#  9   temp        730 non-null    float64
#  10  atemp       730 non-null    float64
#  11  hum         730 non-null    float64
#  12  windspeed   730 non-null    float64
#  13  casual      730 non-null    int64
#  14  registered  730 non-null    int64
#  15  cnt         730 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.4+ KB

# %%
df.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000
# mean   365.500000    2.498630    0.500000    6.526027    0.028767    2.997260
# std    210.877136    1.110184    0.500343    3.450215    0.167266    2.006161
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.250000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    365.500000    3.000000    0.500000    7.000000    0.000000    3.000000
# 75%    547.750000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    730.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000
# mean     0.683562    1.394521   20.319259   23.726322   62.765175   12.763620
# std      0.465405    0.544807    7.506729    8.150308   14.237589    5.195841
# min      0.000000    1.000000    2.424346    3.953480    0.000000    1.500244
# 25%      0.000000    1.000000   13.811885   16.889713   52.000000    9.041650
# 50%      1.000000    1.000000   20.465826   24.368225   62.625000   12.125325
# 75%      1.000000    2.000000   26.880615   30.445775   72.989575   15.625589
# max      1.000000    3.000000   35.328347   42.044800   97.250000   34.000021
#
#             casual   registered          cnt
# count   730.000000   730.000000   730.000000
# mean    849.249315  3658.757534  4508.006849
# std     686.479875  1559.758728  1936.011647
# min       2.000000    20.000000    22.000000
# 25%     316.250000  2502.250000  3169.750000
# 50%     717.000000  3664.500000  4548.500000
# 75%    1096.500000  4783.250000  5966.000000
# max    3410.000000  6946.000000  8714.000000

# %%
type(df[['yr']])
# Out:
# pandas.core.frame.DataFrame

# %%
df.loc[2:6,['windspeed','registered']]
# Out:
#    windspeed  registered
# 2  16.636703        1229
# 3  10.739832        1454
# 4  12.522300        1518
# 5   6.000868        1518
# 6  11.304642        1362

# %%
df.set_index('instant',inplace = True)

# %%
df.head()
# Out:
#              dteday  season  yr  mnth  holiday  weekday  workingday  \
# instant
# 1        01-01-2018       1   0     1        0        6           0
# 2        02-01-2018       1   0     1        0        0           0
# 3        03-01-2018       1   0     1        0        1           1
# 4        04-01-2018       1   0     1        0        2           1
# 5        05-01-2018       1   0     1        0        3           1
#
#          weathersit       temp     atemp      hum  windspeed  casual  \
# instant
# 1                 2  14.110847  18.18125  80.5833  10.749882     331
# 2                 2  14.902598  17.68695  69.6087  16.652113     131
# 3                 1   8.050924   9.47025  43.7273  16.636703     120
# 4                 1   8.200000  10.60610  59.0435  10.739832     108
# 5                 1   9.305237  11.46350  43.6957  12.522300      82
#
#          registered   cnt
# instant
# 1               654   985
# 2               670   801
# 3              1229  1349
# 4              1454  1562
# 5              1518  1600

# %%
df.loc[2:6,['windspeed','registered']]
# Out:
#          windspeed  registered
# instant
# 2        16.652113         670
# 3        16.636703        1229
# 4        10.739832        1454
# 5        12.522300        1518
# 6         6.000868        1518

# %%
df.reset_index()
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  01-01-2018       1   0     1        0        6           0
# 1          2  02-01-2018       1   0     1        0        0           0
# 2          3  03-01-2018       1   0     1        0        1           1
# 3          4  04-01-2018       1   0     1        0        2           1
# 4          5  05-01-2018       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 725      726  27-12-2019       1   1    12        0        4           1
# 726      727  28-12-2019       1   1    12        0        5           1
# 727      728  29-12-2019       1   1    12        0        6           0
# 728      729  30-12-2019       1   1    12        0        0           0
# 729      730  31-12-2019       1   1    12        0        1           1
#
#      weathersit       temp     atemp      hum  windspeed  casual  registered  \
# 0             2  14.110847  18.18125  80.5833  10.749882     331         654
# 1             2  14.902598  17.68695  69.6087  16.652113     131         670
# 2             1   8.050924   9.47025  43.7273  16.636703     120        1229
# 3             1   8.200000  10.60610  59.0435  10.739832     108        1454
# 4             1   9.305237  11.46350  43.6957  12.522300      82        1518
# ..          ...        ...       ...      ...        ...     ...         ...
# 725           2  10.420847  11.33210  65.2917  23.458911     247        1867
# 726           2  10.386653  12.75230  59.0000  10.416557     644        2451
# 727           2  10.386653  12.12000  75.2917   8.333661     159        1182
# 728           1  10.489153  11.58500  48.3333  23.500518     364        1432
# 729           2   8.849153  11.17435  57.7500  10.374682     439        2290
#
#       cnt
# 0     985
# 1     801
# 2    1349
# 3    1562
# 4    1600
# ..    ...
# 725  2114
# 726  3095
# 727  1341
# 728  1796
# 729  2729
#
# [730 rows x 16 columns]

# %%
df2 = df[df['windspeed']>10][['windspeed','atemp','temp','hum']]
df2.head()
# Out:
#          windspeed     atemp       temp      hum
# instant
# 1        10.749882  18.18125  14.110847  80.5833
# 2        16.652113  17.68695  14.902598  69.6087
# 3        16.636703   9.47025   8.050924  43.7273
# 4        10.739832  10.60610   8.200000  59.0435
# 5        12.522300  11.46350   9.305237  43.6957

# %%
df2
# Out:
#          windspeed     atemp       temp      hum
# instant
# 1        10.749882  18.18125  14.110847  80.5833
# 2        16.652113  17.68695  14.902598  69.6087
# 3        16.636703   9.47025   8.050924  43.7273
# 4        10.739832  10.60610   8.200000  59.0435
# 5        12.522300  11.46350   9.305237  43.6957
# ...            ...       ...        ...      ...
# 725      21.208582  11.01665   9.976653  82.3333
# 726      23.458911  11.33210  10.420847  65.2917
# 727      10.416557  12.75230  10.386653  59.0000
# 729      23.500518  11.58500  10.489153  48.3333
# 730      10.374682  11.17435   8.849153  57.7500
#
# [488 rows x 4 columns]

# %%
df2.shape
# Out:
# (488, 4)

# %%
df3 = pd.merge(df,df2,how='inner',on= ['temp','atemp'])
df3.shape
# Out:
# (489, 17)

# %%
df3
# Out:
#          dteday  season  yr  mnth  holiday  weekday  workingday  weathersit  \
# 0    01-01-2018       1   0     1        0        6           0           2
# 1    02-01-2018       1   0     1        0        0           0           2
# 2    03-01-2018       1   0     1        0        1           1           1
# 3    04-01-2018       1   0     1        0        2           1           1
# 4    05-01-2018       1   0     1        0        3           1           1
# ..          ...     ...  ..   ...      ...      ...         ...         ...
# 484  26-12-2019       1   1    12        0        3           1           3
# 485  27-12-2019       1   1    12        0        4           1           2
# 486  28-12-2019       1   1    12        0        5           1           2
# 487  30-12-2019       1   1    12        0        0           0           1
# 488  31-12-2019       1   1    12        0        1           1           2
#
#           temp     atemp    hum_x  windspeed_x  casual  registered   cnt  \
# 0    14.110847  18.18125  80.5833    10.749882     331         654   985
# 1    14.902598  17.68695  69.6087    16.652113     131         670   801
# 2     8.050924   9.47025  43.7273    16.636703     120        1229  1349
# 3     8.200000  10.60610  59.0435    10.739832     108        1454  1562
# 4     9.305237  11.46350  43.6957    12.522300      82        1518  1600
# ..         ...       ...      ...          ...     ...         ...   ...
# 484   9.976653  11.01665  82.3333    21.208582       9         432   441
# 485  10.420847  11.33210  65.2917    23.458911     247        1867  2114
# 486  10.386653  12.75230  59.0000    10.416557     644        2451  3095
# 487  10.489153  11.58500  48.3333    23.500518     364        1432  1796
# 488   8.849153  11.17435  57.7500    10.374682     439        2290  2729
#
#      windspeed_y    hum_y
# 0      10.749882  80.5833
# 1      16.652113  69.6087
# 2      16.636703  43.7273
# 3      10.739832  59.0435
# 4      12.522300  43.6957
# ..           ...      ...
# 484    21.208582  82.3333
# 485    23.458911  65.2917
# 486    10.416557  59.0000
# 487    23.500518  48.3333
# 488    10.374682  57.7500
#
# [489 rows x 17 columns]

# %%
df
# Out:
#              dteday  season  yr  mnth  holiday  weekday  workingday  \
# instant
# 1        01-01-2018       1   0     1        0        6           0
# 2        02-01-2018       1   0     1        0        0           0
# 3        03-01-2018       1   0     1        0        1           1
# 4        04-01-2018       1   0     1        0        2           1
# 5        05-01-2018       1   0     1        0        3           1
# ...             ...     ...  ..   ...      ...      ...         ...
# 726      27-12-2019       1   1    12        0        4           1
# 727      28-12-2019       1   1    12        0        5           1
# 728      29-12-2019       1   1    12        0        6           0
# 729      30-12-2019       1   1    12        0        0           0
# 730      31-12-2019       1   1    12        0        1           1
#
#          weathersit       temp     atemp      hum  windspeed  casual  \
# instant
# 1                 2  14.110847  18.18125  80.5833  10.749882     331
# 2                 2  14.902598  17.68695  69.6087  16.652113     131
# 3                 1   8.050924   9.47025  43.7273  16.636703     120
# 4                 1   8.200000  10.60610  59.0435  10.739832     108
# 5                 1   9.305237  11.46350  43.6957  12.522300      82
# ...             ...        ...       ...      ...        ...     ...
# 726               2  10.420847  11.33210  65.2917  23.458911     247
# 727               2  10.386653  12.75230  59.0000  10.416557     644
# 728               2  10.386653  12.12000  75.2917   8.333661     159
# 729               1  10.489153  11.58500  48.3333  23.500518     364
# 730               2   8.849153  11.17435  57.7500  10.374682     439
#
#          registered   cnt
# instant
# 1               654   985
# 2               670   801
# 3              1229  1349
# 4              1454  1562
# 5              1518  1600
# ...             ...   ...
# 726            1867  2114
# 727            2451  3095
# 728            1182  1341
# 729            1432  1796
# 730            2290  2729
#
# [730 rows x 15 columns]

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 489 entries, 0 to 488
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   dteday       489 non-null    object
#  1   season       489 non-null    int64
#  2   yr           489 non-null    int64
#  3   mnth         489 non-null    int64
#  4   holiday      489 non-null    int64
#  5   weekday      489 non-null    int64
#  6   workingday   489 non-null    int64
#  7   weathersit   489 non-null    int64
#  8   temp         489 non-null    float64
#  9   atemp        489 non-null    float64
#  10  hum_x        489 non-null    float64
#  11  windspeed_x  489 non-null    float64
#  12  casual       489 non-null    int64
#  13  registered   489 non-null    int64
#  14  cnt          489 non-null    int64
#  15  windspeed_y  489 non-null    float64
#  16  hum_y        489 non-null    float64
# dtypes: float64(6), int64(10), object(1)
# memory usage: 65.1+ KB

# %%
df4=pd.concat(axis=0,objs=[df,df2])

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1218 entries, 1 to 730
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   dteday      730 non-null    object
#  1   season      730 non-null    float64
#  2   yr          730 non-null    float64
#  3   mnth        730 non-null    float64
#  4   holiday     730 non-null    float64
#  5   weekday     730 non-null    float64
#  6   workingday  730 non-null    float64
#  7   weathersit  730 non-null    float64
#  8   temp        1218 non-null   float64
#  9   atemp       1218 non-null   float64
#  10  hum         1218 non-null   float64
#  11  windspeed   1218 non-null   float64
#  12  casual      730 non-null    float64
#  13  registered  730 non-null    float64
#  14  cnt         730 non-null    float64
# dtypes: float64(14), object(1)
# memory usage: 152.2+ KB

# %%
df['count_2']= df['cnt'].apply(lambda x: x*2)

# %%
df
# Out:
#              dteday  season  yr  mnth  holiday  weekday  workingday  \
# instant
# 1        01-01-2018       1   0     1        0        6           0
# 2        02-01-2018       1   0     1        0        0           0
# 3        03-01-2018       1   0     1        0        1           1
# 4        04-01-2018       1   0     1        0        2           1
# 5        05-01-2018       1   0     1        0        3           1
# ...             ...     ...  ..   ...      ...      ...         ...
# 726      27-12-2019       1   1    12        0        4           1
# 727      28-12-2019       1   1    12        0        5           1
# 728      29-12-2019       1   1    12        0        6           0
# 729      30-12-2019       1   1    12        0        0           0
# 730      31-12-2019       1   1    12        0        1           1
#
#          weathersit       temp     atemp      hum  windspeed  casual  \
# instant
# 1                 2  14.110847  18.18125  80.5833  10.749882     331
# 2                 2  14.902598  17.68695  69.6087  16.652113     131
# 3                 1   8.050924   9.47025  43.7273  16.636703     120
# 4                 1   8.200000  10.60610  59.0435  10.739832     108
# 5                 1   9.305237  11.46350  43.6957  12.522300      82
# ...             ...        ...       ...      ...        ...     ...
# 726               2  10.420847  11.33210  65.2917  23.458911     247
# 727               2  10.386653  12.75230  59.0000  10.416557     644
# 728               2  10.386653  12.12000  75.2917   8.333661     159
# 729               1  10.489153  11.58500  48.3333  23.500518     364
# 730               2   8.849153  11.17435  57.7500  10.374682     439
#
#          registered   cnt  count_2
# instant
# 1               654   985     1970
# 2               670   801     1602
# 3              1229  1349     2698
# 4              1454  1562     3124
# 5              1518  1600     3200
# ...             ...   ...      ...
# 726            1867  2114     4228
# 727            2451  3095     6190
# 728            1182  1341     2682
# 729            1432  1796     3592
# 730            2290  2729     5458
#
# [730 rows x 16 columns]

# %%
df['s'] = df['dteday'].astype('str')+ ": " + df['cnt'].astype('str')

# %%
df
# Out:
#              dteday  season  yr  mnth  holiday  weekday  workingday  \
# instant
# 1        01-01-2018       1   0     1        0        6           0
# 2        02-01-2018       1   0     1        0        0           0
# 3        03-01-2018       1   0     1        0        1           1
# 4        04-01-2018       1   0     1        0        2           1
# 5        05-01-2018       1   0     1        0        3           1
# ...             ...     ...  ..   ...      ...      ...         ...
# 726      27-12-2019       1   1    12        0        4           1
# 727      28-12-2019       1   1    12        0        5           1
# 728      29-12-2019       1   1    12        0        6           0
# 729      30-12-2019       1   1    12        0        0           0
# 730      31-12-2019       1   1    12        0        1           1
#
#          weathersit       temp     atemp      hum  windspeed  casual  \
# instant
# 1                 2  14.110847  18.18125  80.5833  10.749882     331
# 2                 2  14.902598  17.68695  69.6087  16.652113     131
# 3                 1   8.050924   9.47025  43.7273  16.636703     120
# 4                 1   8.200000  10.60610  59.0435  10.739832     108
# 5                 1   9.305237  11.46350  43.6957  12.522300      82
# ...             ...        ...       ...      ...        ...     ...
# 726               2  10.420847  11.33210  65.2917  23.458911     247
# 727               2  10.386653  12.75230  59.0000  10.416557     644
# 728               2  10.386653  12.12000  75.2917   8.333661     159
# 729               1  10.489153  11.58500  48.3333  23.500518     364
# 730               2   8.849153  11.17435  57.7500  10.374682     439
#
#          registered   cnt  count_2                 s
# instant
# 1               654   985     1970   01-01-2018: 985
# 2               670   801     1602   02-01-2018: 801
# 3              1229  1349     2698  03-01-2018: 1349
# 4              1454  1562     3124  04-01-2018: 1562
# 5              1518  1600     3200  05-01-2018: 1600
# ...             ...   ...      ...               ...
# 726            1867  2114     4228  27-12-2019: 2114
# 727            2451  3095     6190  28-12-2019: 3095
# 728            1182  1341     2682  29-12-2019: 1341
# 729            1432  1796     3592  30-12-2019: 1796
# 730            2290  2729     5458  31-12-2019: 2729
#
# [730 rows x 17 columns]

# %%
df.drop(['count_2','s'],inplace=True,axis=1)

# %%
df
# Out:
#              dteday  season  yr  mnth  holiday  weekday  workingday  \
# instant
# 1        01-01-2018       1   0     1        0        6           0
# 2        02-01-2018       1   0     1        0        0           0
# 3        03-01-2018       1   0     1        0        1           1
# 4        04-01-2018       1   0     1        0        2           1
# 5        05-01-2018       1   0     1        0        3           1
# ...             ...     ...  ..   ...      ...      ...         ...
# 726      27-12-2019       1   1    12        0        4           1
# 727      28-12-2019       1   1    12        0        5           1
# 728      29-12-2019       1   1    12        0        6           0
# 729      30-12-2019       1   1    12        0        0           0
# 730      31-12-2019       1   1    12        0        1           1
#
#          weathersit       temp     atemp      hum  windspeed  casual  \
# instant
# 1                 2  14.110847  18.18125  80.5833  10.749882     331
# 2                 2  14.902598  17.68695  69.6087  16.652113     131
# 3                 1   8.050924   9.47025  43.7273  16.636703     120
# 4                 1   8.200000  10.60610  59.0435  10.739832     108
# 5                 1   9.305237  11.46350  43.6957  12.522300      82
# ...             ...        ...       ...      ...        ...     ...
# 726               2  10.420847  11.33210  65.2917  23.458911     247
# 727               2  10.386653  12.75230  59.0000  10.416557     644
# 728               2  10.386653  12.12000  75.2917   8.333661     159
# 729               1  10.489153  11.58500  48.3333  23.500518     364
# 730               2   8.849153  11.17435  57.7500  10.374682     439
#
#          registered   cnt
# instant
# 1               654   985
# 2               670   801
# 3              1229  1349
# 4              1454  1562
# 5              1518  1600
# ...             ...   ...
# 726            1867  2114
# 727            2451  3095
# 728            1182  1341
# 729            1432  1796
# 730            2290  2729
#
# [730 rows x 15 columns]

# %% [markdown]
# ### `corr()` function explanation
#
# -   **Purpose**: Calculates the correlation coefficient between numerical columns.
# -   **Output**: Returns a correlation matrix, where each cell `(i, j)` represents the correlation between column `i` and column `j`.
# -   **Methods**: By default, it uses Pearson correlation. Other methods like Kendall and Spearman can also be specified.
#
# Let's see the correlation matrix for our `df` DataFrame:

# %%
df.corr(numeric_only=True)
# Out:
#                   season            yr          mnth   holiday   weekday  \
# season      1.000000e+00 -3.279074e-16  8.310321e-01 -0.010868 -0.003081
# yr         -3.279074e-16  1.000000e+00 -5.162656e-16  0.008195 -0.005466
# mnth        8.310321e-01 -5.162656e-16  1.000000e+00  0.018905  0.009523
# holiday    -1.086804e-02  8.195345e-03  1.890483e-02  1.000000 -0.101962
# weekday    -3.081198e-03 -5.466369e-03  9.522969e-03 -0.101962  1.000000
# workingday  1.376178e-02 -2.945396e-03 -4.687953e-03 -0.252948  0.035800
# weathersit  2.130636e-02 -5.032247e-02  4.561335e-02 -0.034395  0.031112
# temp        3.333607e-01  4.878919e-02  2.190833e-01 -0.028764 -0.000168
# atemp       3.420139e-01  4.721519e-02  2.264302e-01 -0.032703 -0.007539
# hum         2.082196e-01 -1.125471e-01  2.249368e-01 -0.015662 -0.052290
# windspeed  -2.296069e-01 -1.162435e-02 -2.080131e-01  0.006257  0.014283
# casual      2.087373e-01  2.505017e-01  1.212079e-01  0.054055  0.059978
# registered  4.103102e-01  5.969106e-01  2.919516e-01 -0.109142  0.057427
# cnt         4.045838e-01  5.697285e-01  2.781909e-01 -0.068764  0.067534
#
#             workingday  weathersit      temp     atemp       hum  windspeed  \
# season        0.013762    0.021306  0.333361  0.342014  0.208220  -0.229607
# yr           -0.002945   -0.050322  0.048789  0.047215 -0.112547  -0.011624
# mnth         -0.004688    0.045613  0.219083  0.226430  0.224937  -0.208013
# holiday      -0.252948   -0.034395 -0.028764 -0.032703 -0.015662   0.006257
# weekday       0.035800    0.031112 -0.000168 -0.007539 -0.052290   0.014283
# workingday    1.000000    0.060236  0.053470  0.052940  0.023202  -0.018666
# weathersit    0.060236    1.000000 -0.119503 -0.120559  0.590277   0.039769
# temp          0.053470   -0.119503  1.000000  0.991696  0.128565  -0.158186
# atemp         0.052940   -0.120559  0.991696  1.000000  0.141512  -0.183876
# hum           0.023202    0.590277  0.128565  0.141512  1.000000  -0.248506
# windspeed    -0.018666    0.039769 -0.158186 -0.183876 -0.248506   1.000000
# casual       -0.517607   -0.246044  0.542731  0.543362 -0.075211  -0.167995
# registered    0.305437   -0.259025  0.539436  0.543678 -0.089212  -0.217914
# cnt           0.062542   -0.295929  0.627044  0.630685 -0.098543  -0.235132
#
#               casual  registered       cnt
# season      0.208737    0.410310  0.404584
# yr          0.250502    0.596911  0.569728
# mnth        0.121208    0.291952  0.278191
# holiday     0.054055   -0.109142 -0.068764
# weekday     0.059978    0.057427  0.067534
# workingday -0.517607    0.305437  0.062542
# weathersit -0.246044   -0.259025 -0.295929
# temp        0.542731    0.539436  0.627044
# atemp       0.543362    0.543678  0.630685
# hum        -0.075211   -0.089212 -0.098543
# windspeed  -0.167995   -0.217914 -0.235132
# casual      1.000000    0.394137  0.672123
# registered  0.394137    1.000000  0.945411
# cnt         0.672123    0.945411  1.000000

# %%
import numpy as np
data = {'birds': ['Cranes', 'Cranes', 'plovers', 'spoonbills', 'spoonbills', 'Cranes', 'plovers', 'Cranes', 'spoonbills', 'spoonbills'], 'age': [3.5, 4, 1.5, np.nan, 6, 3, 5.5, np.nan, 8, 4], 'visits': [2, 4, 3, 4, 3, 4, 2, 2, 3, 2], 'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}

labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

d = pd.DataFrame(data=data,index=labels)
d
# Out:
#         birds  age  visits priority
# a      Cranes  3.5       2      yes
# b      Cranes  4.0       4      yes
# c     plovers  1.5       3       no
# d  spoonbills  NaN       4      yes
# e  spoonbills  6.0       3       no
# f      Cranes  3.0       4       no
# g     plovers  5.5       2       no
# h      Cranes  NaN       2      yes
# i  spoonbills  8.0       3       no
# j  spoonbills  4.0       2       no

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, a to j
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   birds     10 non-null     object
#  1   age       8 non-null      float64
#  2   visits    10 non-null     int64
#  3   priority  10 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 700.0+ bytes

# %%
d.head(2)
# Out:
#     birds  age  visits priority
# a  Cranes  3.5       2      yes
# b  Cranes  4.0       4      yes

# %%
d[['birds','age']]
# Out:
#         birds  age
# a      Cranes  3.5
# b      Cranes  4.0
# c     plovers  1.5
# d  spoonbills  NaN
# e  spoonbills  6.0
# f      Cranes  3.0
# g     plovers  5.5
# h      Cranes  NaN
# i  spoonbills  8.0
# j  spoonbills  4.0

# %%
 #select [2, 3, 7] rows and in columns ['birds', 'age', 'visits']
d.loc[['b','c','g'],['birds', 'age', 'visits']]
# Out:
#      birds  age  visits
# b   Cranes  4.0       4
# c  plovers  1.5       3
# g  plovers  5.5       2

# %%
#select the rows where the number of visits is less than 4
d[d['visits']<4]
# Out:
#         birds  age  visits priority
# a      Cranes  3.5       2      yes
# c     plovers  1.5       3       no
# e  spoonbills  6.0       3       no
# g     plovers  5.5       2       no
# h      Cranes  NaN       2      yes
# i  spoonbills  8.0       3       no
# j  spoonbills  4.0       2       no

# %%
d[np.isnan(d['age'])][['birds','visits']]
# Out:
#         birds  visits
# d  spoonbills       4
# h      Cranes       2

# %%
# Select the rows where the birds is a Cranes and the age is less than 4
d[d['birds']=='Cranes'][d['age']<4]
# Out:
# /tmp/ipykernel_18917/2259311388.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   d[d['birds']=='Cranes'][d['age']<4]
#     birds  age  visits priority
# a  Cranes  3.5       2      yes
# f  Cranes  3.0       4       no

# %%
#Select the rows the age is between 2 and 4(inclusive)
d[(d['age'] >= 2) & (d['age'] <= 4)]
# Out:
#         birds  age  visits priority
# a      Cranes  3.5       2      yes
# b      Cranes  4.0       4      yes
# f      Cranes  3.0       4       no
# j  spoonbills  4.0       2       no

# %%
#Find the total number of visits of the bird Cranes
d[d['birds']=='Cranes']['visits'].sum()
# Out:
# np.int64(12)

# %%
#Calculate the mean age for each different birds in dataframe.
d.groupby('birds')['age'].mean()
# Out:
# birds
# Cranes        3.5
# plovers       3.5
# spoonbills    6.0
# Name: age, dtype: float64

# %%
#Append a new row 'k' to dataframe with your choice of values for each column. Then delete that row to return the original DataFrame.
d['nw']=d['age'].apply(lambda x: x*2)
d.drop('nw',axis=1,inplace=True)
d
# Out:
#         birds  age  visits priority
# a      Cranes  3.5       2      yes
# b      Cranes  4.0       4      yes
# c     plovers  1.5       3       no
# d  spoonbills  NaN       4      yes
# e  spoonbills  6.0       3       no
# f      Cranes  3.0       4       no
# g     plovers  5.5       2       no
# h      Cranes  NaN       2      yes
# i  spoonbills  8.0       3       no
# j  spoonbills  4.0       2       no

# %%
#Find the number of each type of birds in dataframe (Counts)
d.groupby('birds').size()
# Out:
# birds
# Cranes        4
# plovers       2
# spoonbills    4
# dtype: int64

# %%
#Sort dataframe (birds) first by the values in the 'age' in decending order, then by the value in the 'visits' column in ascending order.
d.sort_values(by=['age','visits'],ascending=[False,True])
# Out:
#         birds  age  visits priority
# i  spoonbills  8.0       3       no
# e  spoonbills  6.0       3       no
# g     plovers  5.5       2       no
# j  spoonbills  4.0       2       no
# b      Cranes  4.0       4      yes
# a      Cranes  3.5       2      yes
# f      Cranes  3.0       4       no
# c     plovers  1.5       3       no
# h      Cranes  NaN       2      yes
# d  spoonbills  NaN       4      yes

# %%
 #Replace the priority column values with'yes' should be 1 and 'no' should be 0
d.loc[d['priority'] == 'yes', 'priority'] = 1
d.loc[d['priority'] == 'no', 'priority'] = 0
d
# Out:
#         birds  age  visits priority
# a      Cranes  3.5       2        1
# b      Cranes  4.0       4        1
# c     plovers  1.5       3        0
# d  spoonbills  NaN       4        1
# e  spoonbills  6.0       3        0
# f      Cranes  3.0       4        0
# g     plovers  5.5       2        0
# h      Cranes  NaN       2        1
# i  spoonbills  8.0       3        0
# j  spoonbills  4.0       2        0

# %%
#In the 'birds' column, change the 'Cranes' entries to 'trumpeters'.
d.loc[d['birds']=='Cranes','birds']='trumpeters'
d
# Out:
#         birds  age  visits priority
# a  trumpeters  3.5       2        1
# b  trumpeters  4.0       4        1
# c     plovers  1.5       3        0
# d  spoonbills  NaN       4        1
# e  spoonbills  6.0       3        0
# f  trumpeters  3.0       4        0
# g     plovers  5.5       2        0
# h  trumpeters  NaN       2        1
# i  spoonbills  8.0       3        0
# j  spoonbills  4.0       2        0
